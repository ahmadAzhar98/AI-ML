# %% [markdown]
# ## Static vs Dynamic typing

# %% [markdown]
# For dynamic typing we dont need to specify data type while intializing for static

# %% [markdown]
# ### Variable is a container to store data.

# %% [markdown]
# ## Static vs dynamic variables

# %% [markdown]
# static variables store data in the stack memory whereas dynamic variables store data in the heap memory. This is crucial for static variable because this makes data acessable throughout program.

# %% [markdown]
# ## Variable types

# %% [markdown]
# - string
# - floating point number
# - whole number

# %% [markdown]
# ## Usage

# %%
numericVariable = 100 

# variable following camelcase convention, in this value vs literal are same. 
# Just like this case there is a float point and string literals

# %% [markdown]
# value vs literal. Value is calculated through some computation whereas literal is hardcoded value assigned.

# %% [markdown]
# ## Compiled vs interpreted language

# %% [markdown]
# For complie language the entire code is translated machine code before execution.
# While interpreted language tranlates and execute at runtime.

# %% [markdown]
# ## Compile time  vs run time

# %% [markdown]
# Compile time: The phase when entire code is converted into machine code. Example of compile time error int x = 'hi';
# Run time: Now the translated code is executed (the time it takes to execute the code).
